# %%
# !pip install --no-cache-dir -e .
# !pip install gmpy2
# Out:
# Obtaining file:///Users/han/python-shogi
# Installing collected packages: python-shogi
#   Attempting uninstall: python-shogi
#     Found existing installation: python-shogi 1.0.14
#     Uninstalling python-shogi-1.0.14:
#       Successfully uninstalled python-shogi-1.0.14
#   Running setup.py develop for python-shogi
# Successfully installed python-shogi-1.0.14

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import shogi

from shogi.common import *
from shogi.features import *
from shogi.player.policy_player import PolicyValuePlayer
from shogi.network.policy import PolicyNetwork

import gmpy2

# %%
shogi.Board()
# Out:
# Board('rbsgk/4p/5/P4/KGSBR b - 1')

# %%
import random

def whos_turn(turn):
    return '上(後手)' if turn else '下(先手)'

def legal_moves_list():
    for i, s_name in enumerate(shogi.SQUARE_NAMES):
        print(f'{s_name} ', end='')
        if (i+1)%5 == 0:
            print('')
    print('-------------------')
    temp_lst = []
    for i in board.legal_moves:
        temp_lst.append(i.usi())
    return temp_lst

def select_move_from_list(temp_lst):
    return random.sample(temp_lst,k=1)

n = 0

board = shogi.Board()
player1 = PolicyValuePlayer()
player1.isready()

result = ''

print(board.kif_str())

while True:
    n += 1
    print('------------------------------------------------------------------------')
    print(f'------------------------Start Turn {n} : {whos_turn(board.turn)}------------------------')
    print('------------------------------------------------------------------------')
    
    if n%2 == 1:
        print('PLAYER 1')
        selected = player1.select_move()
        if selected == 'q':
            result = 'D'
            break
    else: 
        print(f'RANDOM PLAYER')

        legal_moves = legal_moves_list()
#         print(f'Legal Moves List : {legal_moves}')

        if len(legal_moves)==0:
            print("There is no Legal Move : Draw")
            result = 'D'
            break
     
        selected = select_move_from_list(legal_moves)[0]

    print(f'Selected : {selected}')
    print(f'--------------Trun({n}) : Move from {selected[:2]} to {selected[-2:]}--------------')
    board.push_usi(selected)
    player1.board.push_usi(selected)
    print(board.kif_str())

    print(f'is_Check : {board.is_check()}')
    print('------------------------------------------------------------------------')
    print(f'---------------------------------End Turn {n}---------------------------------')
    print('------------------------------------------------------------------------')
    print('')
    print('')

    if board.is_checkmate():
        print(f'CHECK MATE : {board.is_checkmate()}')
        print(f'GAME OVER : {board.is_game_over()}')
        print(board.turn)
        break
# Out:
# readyok
# ------------------------------------------------------------------------
# ------------------------Start Turn 1 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v飛v角v銀v金v玉|一
# | ・ ・ ・ ・v歩|二
# | ・ ・ ・ ・ ・|三
# | 歩 ・ ・ ・ ・|四
# | 玉 金 銀 角 飛|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 4e4d
# --------------Trun(1) : Move from 4e to 4d--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v飛v角v銀v金v玉|一
# | ・ ・ ・ ・v歩|二
# | ・ ・ ・ ・ ・|三
# | 歩 金 ・ ・ ・|四
# | 玉 ・ 銀 角 飛|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 1---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 2 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v飛v角v銀v金v玉|一
# | ・ ・ ・ ・v歩|二
# | ・ ・ ・ ・ ・|三
# | 歩 金 ・ ・ ・|四
# | 玉 ・ 銀 角 飛|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 1a2b
# --------------Trun(2) : Move from 1a to 2b--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v飛v角v銀v金 ・|一
# | ・ ・ ・v玉v歩|二
# | ・ ・ ・ ・ ・|三
# | 歩 金 ・ ・ ・|四
# | 玉 ・ 銀 角 飛|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 2---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 3 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v飛v角v銀v金 ・|一
# | ・ ・ ・v玉v歩|二
# | ・ ・ ・ ・ ・|三
# | 歩 金 ・ ・ ・|四
# | 玉 ・ 銀 角 飛|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 2e5b
# --------------Trun(3) : Move from 2e to 5b--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v飛v角v銀v金 ・|一
# | 角 ・ ・v玉v歩|二
# | ・ ・ ・ ・ ・|三
# | 歩 金 ・ ・ ・|四
# | 玉 ・ 銀 ・ 飛|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 3---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 4 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v飛v角v銀v金 ・|一
# | 角 ・ ・v玉v歩|二
# | ・ ・ ・ ・ ・|三
# | 歩 金 ・ ・ ・|四
# | 玉 ・ 銀 ・ 飛|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 5a5b
# --------------Trun(4) : Move from 5a to 5b--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・v玉v歩|二
# | ・ ・ ・ ・ ・|三
# | 歩 金 ・ ・ ・|四
# | 玉 ・ 銀 ・ 飛|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 4---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 5 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・v玉v歩|二
# | ・ ・ ・ ・ ・|三
# | 歩 金 ・ ・ ・|四
# | 玉 ・ 銀 ・ 飛|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 1e1b
# --------------Trun(5) : Move from 1e to 1b--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・v玉 飛|二
# | ・ ・ ・ ・ ・|三
# | 歩 金 ・ ・ ・|四
# | 玉 ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# is_Check : True
# ------------------------------------------------------------------------
# ---------------------------------End Turn 5---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 6 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・v玉 飛|二
# | ・ ・ ・ ・ ・|三
# | 歩 金 ・ ・ ・|四
# | 玉 ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 2b1b
# --------------Trun(6) : Move from 2b to 1b--------------
# 後手の持駒：　飛　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・ ・v玉|二
# | ・ ・ ・ ・ ・|三
# | 歩 金 ・ ・ ・|四
# | 玉 ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 6---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 7 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・ ・v玉|二
# | ・ ・ ・ ・ ・|三
# | 歩 金 ・ ・ ・|四
# | 玉 ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# PLAYER 1
# Selected : 5d5c
# --------------Trun(7) : Move from 5d to 5c--------------
# 後手の持駒：　飛　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・ ・v玉|二
# | 歩 ・ ・ ・ ・|三
# | ・ 金 ・ ・ ・|四
# | 玉 ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 7---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 8 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・ ・v玉|二
# | 歩 ・ ・ ・ ・|三
# | ・ 金 ・ ・ ・|四
# | 玉 ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 1b2b
# --------------Trun(8) : Move from 1b to 2b--------------
# 後手の持駒：　飛　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・v玉 ・|二
# | 歩 ・ ・ ・ ・|三
# | ・ 金 ・ ・ ・|四
# | 玉 ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 8---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 9 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・v玉 ・|二
# | 歩 ・ ・ ・ ・|三
# | ・ 金 ・ ・ ・|四
# | 玉 ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# PLAYER 1
# Selected : 4d5d
# --------------Trun(9) : Move from 4d to 5d--------------
# 後手の持駒：　飛　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・v玉 ・|二
# | 歩 ・ ・ ・ ・|三
# | 金 ・ ・ ・ ・|四
# | 玉 ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 9---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 10 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・v玉 ・|二
# | 歩 ・ ・ ・ ・|三
# | 金 ・ ・ ・ ・|四
# | 玉 ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : R*1c
# --------------Trun(10) : Move from R* to 1c--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・v玉 ・|二
# | 歩 ・ ・ ・v飛|三
# | 金 ・ ・ ・ ・|四
# | 玉 ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 10---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 11 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・v玉 ・|二
# | 歩 ・ ・ ・v飛|三
# | 金 ・ ・ ・ ・|四
# | 玉 ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# PLAYER 1
# Selected : 5e4d
# --------------Trun(11) : Move from 5e to 4d--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・v玉 ・|二
# | 歩 ・ ・ ・v飛|三
# | 金 玉 ・ ・ ・|四
# | ・ ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 11---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 12 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・v角v銀v金 ・|一
# |v飛 ・ ・v玉 ・|二
# | 歩 ・ ・ ・v飛|三
# | 金 玉 ・ ・ ・|四
# | ・ ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 4a2c
# --------------Trun(12) : Move from 4a to 2c--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀v金 ・|一
# |v飛 ・ ・v玉 ・|二
# | 歩 ・ ・v角v飛|三
# | 金 玉 ・ ・ ・|四
# | ・ ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 12---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 13 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀v金 ・|一
# |v飛 ・ ・v玉 ・|二
# | 歩 ・ ・v角v飛|三
# | 金 玉 ・ ・ ・|四
# | ・ ・ 銀 ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# PLAYER 1
# Selected : 3e3d
# --------------Trun(13) : Move from 3e to 3d--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀v金 ・|一
# |v飛 ・ ・v玉 ・|二
# | 歩 ・ ・v角v飛|三
# | 金 玉 銀 ・ ・|四
# | ・ ・ ・ ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 13---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 14 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀v金 ・|一
# |v飛 ・ ・v玉 ・|二
# | 歩 ・ ・v角v飛|三
# | 金 玉 銀 ・ ・|四
# | ・ ・ ・ ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 2b3b
# --------------Trun(14) : Move from 2b to 3b--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀v金 ・|一
# |v飛 ・v玉 ・ ・|二
# | 歩 ・ ・v角v飛|三
# | 金 玉 銀 ・ ・|四
# | ・ ・ ・ ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 14---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 15 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀v金 ・|一
# |v飛 ・v玉 ・ ・|二
# | 歩 ・ ・v角v飛|三
# | 金 玉 銀 ・ ・|四
# | ・ ・ ・ ・ ・|五
# +---------------------------+
# 先手の持駒：　歩
# PLAYER 1
# Selected : 3d2e
# --------------Trun(15) : Move from 3d to 2e--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀v金 ・|一
# |v飛 ・v玉 ・ ・|二
# | 歩 ・ ・v角v飛|三
# | 金 玉 ・ ・ ・|四
# | ・ ・ ・ 銀 ・|五
# +---------------------------+
# 先手の持駒：　歩
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 15---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 16 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀v金 ・|一
# |v飛 ・v玉 ・ ・|二
# | 歩 ・ ・v角v飛|三
# | 金 玉 ・ ・ ・|四
# | ・ ・ ・ 銀 ・|五
# +---------------------------+
# 先手の持駒：　歩
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 1c1e+
# --------------Trun(16) : Move from 1c to e+--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀v金 ・|一
# |v飛 ・v玉 ・ ・|二
# | 歩 ・ ・v角 ・|三
# | 金 玉 ・ ・ ・|四
# | ・ ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　歩
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 16---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 17 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀v金 ・|一
# |v飛 ・v玉 ・ ・|二
# | 歩 ・ ・v角 ・|三
# | 金 玉 ・ ・ ・|四
# | ・ ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　歩
# PLAYER 1
# Selected : P*3e
# --------------Trun(17) : Move from P* to 3e--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀v金 ・|一
# |v飛 ・v玉 ・ ・|二
# | 歩 ・ ・v角 ・|三
# | 金 玉 ・ ・ ・|四
# | ・ ・ 歩 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 17---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 18 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀v金 ・|一
# |v飛 ・v玉 ・ ・|二
# | 歩 ・ ・v角 ・|三
# | 金 玉 ・ ・ ・|四
# | ・ ・ 歩 銀v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 2a2b
# --------------Trun(18) : Move from 2a to 2b--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# |v飛 ・v玉v金 ・|二
# | 歩 ・ ・v角 ・|三
# | 金 玉 ・ ・ ・|四
# | ・ ・ 歩 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 18---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 19 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# |v飛 ・v玉v金 ・|二
# | 歩 ・ ・v角 ・|三
# | 金 玉 ・ ・ ・|四
# | ・ ・ 歩 銀v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 3e3d
# --------------Trun(19) : Move from 3e to 3d--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# |v飛 ・v玉v金 ・|二
# | 歩 ・ ・v角 ・|三
# | 金 玉 歩 ・ ・|四
# | ・ ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 19---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 20 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# |v飛 ・v玉v金 ・|二
# | 歩 ・ ・v角 ・|三
# | 金 玉 歩 ・ ・|四
# | ・ ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 2c1d
# --------------Trun(20) : Move from 2c to 1d--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# |v飛 ・v玉v金 ・|二
# | 歩 ・ ・ ・ ・|三
# | 金 玉 歩 ・v角|四
# | ・ ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 20---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 21 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# |v飛 ・v玉v金 ・|二
# | 歩 ・ ・ ・ ・|三
# | 金 玉 歩 ・v角|四
# | ・ ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 4d4e
# --------------Trun(21) : Move from 4d to 4e--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# |v飛 ・v玉v金 ・|二
# | 歩 ・ ・ ・ ・|三
# | 金 ・ 歩 ・v角|四
# | ・ 玉 ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 21---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 22 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# |v飛 ・v玉v金 ・|二
# | 歩 ・ ・ ・ ・|三
# | 金 ・ 歩 ・v角|四
# | ・ 玉 ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : B*5a
# --------------Trun(22) : Move from B* to 5a--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v角 ・v銀 ・ ・|一
# |v飛 ・v玉v金 ・|二
# | 歩 ・ ・ ・ ・|三
# | 金 ・ 歩 ・v角|四
# | ・ 玉 ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 22---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 23 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v角 ・v銀 ・ ・|一
# |v飛 ・v玉v金 ・|二
# | 歩 ・ ・ ・ ・|三
# | 金 ・ 歩 ・v角|四
# | ・ 玉 ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 5c5b
# --------------Trun(23) : Move from 5c to 5b--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v角 ・v銀 ・ ・|一
# | 歩 ・v玉v金 ・|二
# | ・ ・ ・ ・ ・|三
# | 金 ・ 歩 ・v角|四
# | ・ 玉 ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　飛
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 23---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 24 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v角 ・v銀 ・ ・|一
# | 歩 ・v玉v金 ・|二
# | ・ ・ ・ ・ ・|三
# | 金 ・ 歩 ・v角|四
# | ・ 玉 ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　飛
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 2b3c
# --------------Trun(24) : Move from 2b to 3c--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v角 ・v銀 ・ ・|一
# | 歩 ・v玉 ・ ・|二
# | ・ ・v金 ・ ・|三
# | 金 ・ 歩 ・v角|四
# | ・ 玉 ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　飛
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 24---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 25 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v角 ・v銀 ・ ・|一
# | 歩 ・v玉 ・ ・|二
# | ・ ・v金 ・ ・|三
# | 金 ・ 歩 ・v角|四
# | ・ 玉 ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　飛
# PLAYER 1
# Selected : 4e5e
# --------------Trun(25) : Move from 4e to 5e--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v角 ・v銀 ・ ・|一
# | 歩 ・v玉 ・ ・|二
# | ・ ・v金 ・ ・|三
# | 金 ・ 歩 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　飛
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 25---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 26 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# |v角 ・v銀 ・ ・|一
# | 歩 ・v玉 ・ ・|二
# | ・ ・v金 ・ ・|三
# | 金 ・ 歩 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　飛
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 3c3d
# --------------Trun(26) : Move from 3c to 3d--------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# |v角 ・v銀 ・ ・|一
# | 歩 ・v玉 ・ ・|二
# | ・ ・ ・ ・ ・|三
# | 金 ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　飛
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 26---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 27 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# |v角 ・v銀 ・ ・|一
# | 歩 ・v玉 ・ ・|二
# | ・ ・ ・ ・ ・|三
# | 金 ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　飛
# PLAYER 1
# Selected : R*3c
# --------------Trun(27) : Move from R* to 3c--------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# |v角 ・v銀 ・ ・|一
# | 歩 ・v玉 ・ ・|二
# | ・ ・ 飛 ・ ・|三
# | 金 ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : True
# ------------------------------------------------------------------------
# ---------------------------------End Turn 27---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 28 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# |v角 ・v銀 ・ ・|一
# | 歩 ・v玉 ・ ・|二
# | ・ ・ 飛 ・ ・|三
# | 金 ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 5a3c
# --------------Trun(28) : Move from 5a to 3c--------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# | 歩 ・v玉 ・ ・|二
# | ・ ・v角 ・ ・|三
# | 金 ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : True
# ------------------------------------------------------------------------
# ---------------------------------End Turn 28---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 29 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# | 歩 ・v玉 ・ ・|二
# | ・ ・v角 ・ ・|三
# | 金 ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 5d4d
# --------------Trun(29) : Move from 5d to 4d--------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# | 歩 ・v玉 ・ ・|二
# | ・ ・v角 ・ ・|三
# | ・ 金v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 29---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 30 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# | 歩 ・v玉 ・ ・|二
# | ・ ・v角 ・ ・|三
# | ・ 金v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 3b2c
# --------------Trun(30) : Move from 3b to 2c--------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# | 歩 ・ ・ ・ ・|二
# | ・ ・v角v玉 ・|三
# | ・ 金v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 30---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 31 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# | 歩 ・ ・ ・ ・|二
# | ・ ・v角v玉 ・|三
# | ・ 金v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 4d3c
# --------------Trun(31) : Move from 4d to 3c--------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# | 歩 ・ ・ ・ ・|二
# | ・ ・ 金v玉 ・|三
# | ・ ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　角
# is_Check : True
# ------------------------------------------------------------------------
# ---------------------------------End Turn 31---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 32 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# | 歩 ・ ・ ・ ・|二
# | ・ ・ 金v玉 ・|三
# | ・ ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　角
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 2c3c
# --------------Trun(32) : Move from 2c to 3c--------------
# 後手の持駒：　飛　金　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# | 歩 ・ ・ ・ ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　角
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 32---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 33 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　金　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ ・|一
# | 歩 ・ ・ ・ ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：　角
# PLAYER 1
# Selected : B*1a
# --------------Trun(33) : Move from B* to 1a--------------
# 後手の持駒：　飛　金　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・ ・ ・ ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : True
# ------------------------------------------------------------------------
# ---------------------------------End Turn 33---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 34 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　金　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・ ・ ・ ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : G*2b
# --------------Trun(34) : Move from G* to 2b--------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・ ・v金 ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 34---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 35 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・ ・v金 ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・v金 ・v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 5e5d
# --------------Trun(35) : Move from 5e to 5d--------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・ ・v金 ・|二
# | ・ ・v玉 ・ ・|三
# | 玉 ・v金 ・v角|四
# | ・ ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 35---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 36 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・ ・v金 ・|二
# | ・ ・v玉 ・ ・|三
# | 玉 ・v金 ・v角|四
# | ・ ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 3d2d
# --------------Trun(36) : Move from 3d to 2d--------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・ ・v金 ・|二
# | ・ ・v玉 ・ ・|三
# | 玉 ・ ・v金v角|四
# | ・ ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 36---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 37 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・ ・v金 ・|二
# | ・ ・v玉 ・ ・|三
# | 玉 ・ ・v金v角|四
# | ・ ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 5d4e
# --------------Trun(37) : Move from 5d to 4e--------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・ ・v金 ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・ ・v金v角|四
# | ・ 玉 ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 37---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 38 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　飛　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・ ・v金 ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・ ・v金v角|四
# | ・ 玉 ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : R*3b
# --------------Trun(38) : Move from R* to 3b--------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・v飛v金 ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・ ・v金v角|四
# | ・ 玉 ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 38---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 39 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・v飛v金 ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・ ・v金v角|四
# | ・ 玉 ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 4e5e
# --------------Trun(39) : Move from 4e to 5e--------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・v飛v金 ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・ ・v金v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 39---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 40 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・v飛v金 ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・ ・v金v角|四
# | 玉 ・ ・ 銀v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 2d3e
# --------------Trun(40) : Move from 2d to 3e--------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・v飛v金 ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・ ・ ・v角|四
# | 玉 ・v金 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 40---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 41 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・v飛v金 ・|二
# | ・ ・v玉 ・ ・|三
# | ・ ・ ・ ・v角|四
# | 玉 ・v金 銀v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 5e5d
# --------------Trun(41) : Move from 5e to 5d--------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・v飛v金 ・|二
# | ・ ・v玉 ・ ・|三
# | 玉 ・ ・ ・v角|四
# | ・ ・v金 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 41---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 42 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩 ・v飛v金 ・|二
# | ・ ・v玉 ・ ・|三
# | 玉 ・ ・ ・v角|四
# | ・ ・v金 銀v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 3b4b
# --------------Trun(42) : Move from 3b to 4b--------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩v飛 ・v金 ・|二
# | ・ ・v玉 ・ ・|三
# | 玉 ・ ・ ・v角|四
# | ・ ・v金 銀v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 42---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 43 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩v飛 ・v金 ・|二
# | ・ ・v玉 ・ ・|三
# | 玉 ・ ・ ・v角|四
# | ・ ・v金 銀v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 2e3d
# --------------Trun(43) : Move from 2e to 3d--------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩v飛 ・v金 ・|二
# | ・ ・v玉 ・ ・|三
# | 玉 ・ 銀 ・v角|四
# | ・ ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : True
# ------------------------------------------------------------------------
# ---------------------------------End Turn 43---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 44 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩v飛 ・v金 ・|二
# | ・ ・v玉 ・ ・|三
# | 玉 ・ 銀 ・v角|四
# | ・ ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 3c3d
# --------------Trun(44) : Move from 3c to 3d--------------
# 後手の持駒：　銀　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩v飛 ・v金 ・|二
# | ・ ・ ・ ・ ・|三
# | 玉 ・v玉 ・v角|四
# | ・ ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 44---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 45 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　銀　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩v飛 ・v金 ・|二
# | ・ ・ ・ ・ ・|三
# | 玉 ・v玉 ・v角|四
# | ・ ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 5d5e
# --------------Trun(45) : Move from 5d to 5e--------------
# 後手の持駒：　銀　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩v飛 ・v金 ・|二
# | ・ ・ ・ ・ ・|三
# | ・ ・v玉 ・v角|四
# | 玉 ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 45---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 46 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　銀　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩v飛 ・v金 ・|二
# | ・ ・ ・ ・ ・|三
# | ・ ・v玉 ・v角|四
# | 玉 ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 1d2c
# --------------Trun(46) : Move from 1d to 2c--------------
# 後手の持駒：　銀　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩v飛 ・v金 ・|二
# | ・ ・ ・v角 ・|三
# | ・ ・v玉 ・ ・|四
# | 玉 ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 46---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 47 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　銀　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ ・v銀 ・ 角|一
# | 歩v飛 ・v金 ・|二
# | ・ ・ ・v角 ・|三
# | ・ ・v玉 ・ ・|四
# | 玉 ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 5b5a+
# --------------Trun(47) : Move from 5b to a+--------------
# 後手の持駒：　銀　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | と ・v銀 ・ 角|一
# | ・v飛 ・v金 ・|二
# | ・ ・ ・v角 ・|三
# | ・ ・v玉 ・ ・|四
# | 玉 ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 47---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 48 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　銀　歩
#   5 ４ ３ ２ １
# +---------------------------+
# | と ・v銀 ・ 角|一
# | ・v飛 ・v金 ・|二
# | ・ ・ ・v角 ・|三
# | ・ ・v玉 ・ ・|四
# | 玉 ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : P*1c
# --------------Trun(48) : Move from P* to 1c--------------
# 後手の持駒：　銀
#   5 ４ ３ ２ １
# +---------------------------+
# | と ・v銀 ・ 角|一
# | ・v飛 ・v金 ・|二
# | ・ ・ ・v角v歩|三
# | ・ ・v玉 ・ ・|四
# | 玉 ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 48---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 49 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　銀
#   5 ４ ３ ２ １
# +---------------------------+
# | と ・v銀 ・ 角|一
# | ・v飛 ・v金 ・|二
# | ・ ・ ・v角v歩|三
# | ・ ・v玉 ・ ・|四
# | 玉 ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 5a4a
# --------------Trun(49) : Move from 5a to 4a--------------
# 後手の持駒：　銀
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ とv銀 ・ 角|一
# | ・v飛 ・v金 ・|二
# | ・ ・ ・v角v歩|三
# | ・ ・v玉 ・ ・|四
# | 玉 ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 49---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 50 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　銀
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ とv銀 ・ 角|一
# | ・v飛 ・v金 ・|二
# | ・ ・ ・v角v歩|三
# | ・ ・v玉 ・ ・|四
# | 玉 ・v金 ・v馬|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 3d2e
# --------------Trun(50) : Move from 3d to 2e--------------
# 後手の持駒：　銀
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ とv銀 ・ 角|一
# | ・v飛 ・v金 ・|二
# | ・ ・ ・v角v歩|三
# | ・ ・ ・ ・ ・|四
# | 玉 ・v金v玉v馬|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 50---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 51 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　銀
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ とv銀 ・ 角|一
# | ・v飛 ・v金 ・|二
# | ・ ・ ・v角v歩|三
# | ・ ・ ・ ・ ・|四
# | 玉 ・v金v玉v馬|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 1a2b+
# --------------Trun(51) : Move from 1a to b+--------------
# 後手の持駒：　銀
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ とv銀 ・ ・|一
# | ・v飛 ・ 全 ・|二
# | ・ ・ ・v角v歩|三
# | ・ ・ ・ ・ ・|四
# | 玉 ・v金v玉v馬|五
# +---------------------------+
# 先手の持駒：　金
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 51---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 52 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　銀
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ とv銀 ・ ・|一
# | ・v飛 ・ 全 ・|二
# | ・ ・ ・v角v歩|三
# | ・ ・ ・ ・ ・|四
# | 玉 ・v金v玉v馬|五
# +---------------------------+
# 先手の持駒：　金
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : S*4e
# --------------Trun(52) : Move from S* to 4e--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ とv銀 ・ ・|一
# | ・v飛 ・ 全 ・|二
# | ・ ・ ・v角v歩|三
# | ・ ・ ・ ・ ・|四
# | 玉v銀v金v玉v馬|五
# +---------------------------+
# 先手の持駒：　金
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 52---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 53 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | ・ とv銀 ・ ・|一
# | ・v飛 ・ 全 ・|二
# | ・ ・ ・v角v歩|三
# | ・ ・ ・ ・ ・|四
# | 玉v銀v金v玉v馬|五
# +---------------------------+
# 先手の持駒：　金
# PLAYER 1
# Selected : 4a5a
# --------------Trun(53) : Move from 4a to 5a--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | と ・v銀 ・ ・|一
# | ・v飛 ・ 全 ・|二
# | ・ ・ ・v角v歩|三
# ...
# Selected : 1d2c
# --------------Trun(154) : Move from 1d to 2c--------------
# 後手の持駒：　金
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ 飛 ・ ・|一
# | ・ ・ ・ ・ 圭|二
# | 玉 ・ 角v玉 ・|三
# | と ・v銀 ・ ・|四
# | ・ ・ ・vと 角|五
# +---------------------------+
# 先手の持駒：　飛
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 154---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 155 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　金
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ 飛 ・ ・|一
# | ・ ・ ・ ・ 圭|二
# | 玉 ・ 角v玉 ・|三
# | と ・v銀 ・ ・|四
# | ・ ・ ・vと 角|五
# +---------------------------+
# 先手の持駒：　飛
# PLAYER 1
# Selected : 3a1a+
# --------------Trun(155) : Move from 3a to a+--------------
# 後手の持駒：　金
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・ ・ ・ 圭|二
# | 玉 ・ 角v玉 ・|三
# | と ・v銀 ・ ・|四
# | ・ ・ ・vと 角|五
# +---------------------------+
# 先手の持駒：　飛
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 155---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 156 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　金
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・ ・ ・ 圭|二
# | 玉 ・ 角v玉 ・|三
# | と ・v銀 ・ ・|四
# | ・ ・ ・vと 角|五
# +---------------------------+
# 先手の持駒：　飛
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : G*2d
# --------------Trun(156) : Move from G* to 2d--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・ ・ ・ 圭|二
# | 玉 ・ 角v玉 ・|三
# | と ・v銀v金 ・|四
# | ・ ・ ・vと 角|五
# +---------------------------+
# 先手の持駒：　飛
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 156---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 157 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・ ・ ・ 圭|二
# | 玉 ・ 角v玉 ・|三
# | と ・v銀v金 ・|四
# | ・ ・ ・vと 角|五
# +---------------------------+
# 先手の持駒：　飛
# PLAYER 1
# Selected : 5c4d
# --------------Trun(157) : Move from 5c to 4d--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・ ・ ・ 圭|二
# | ・ ・ 角v玉 ・|三
# | と 玉v銀v金 ・|四
# | ・ ・ ・vと 角|五
# +---------------------------+
# 先手の持駒：　飛
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 157---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 158 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・ ・ ・ 圭|二
# | ・ ・ 角v玉 ・|三
# | と 玉v銀v金 ・|四
# | ・ ・ ・vと 角|五
# +---------------------------+
# 先手の持駒：　飛
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 2e1e
# --------------Trun(158) : Move from 2e to 1e--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・ ・ ・ 圭|二
# | ・ ・ 角v玉 ・|三
# | と 玉v銀v金 ・|四
# | ・ ・ ・ ・vと|五
# +---------------------------+
# 先手の持駒：　飛
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 158---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 159 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・ ・ ・ 圭|二
# | ・ ・ 角v玉 ・|三
# | と 玉v銀v金 ・|四
# | ・ ・ ・ ・vと|五
# +---------------------------+
# 先手の持駒：　飛
# PLAYER 1
# Selected : R*1c
# --------------Trun(159) : Move from R* to 1c--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・ ・ ・ 圭|二
# | ・ ・ 角v玉 飛|三
# | と 玉v銀v金 ・|四
# | ・ ・ ・ ・vと|五
# +---------------------------+
# 先手の持駒：
# is_Check : True
# ------------------------------------------------------------------------
# ---------------------------------End Turn 159---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 160 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・ ・ ・ 圭|二
# | ・ ・ 角v玉 飛|三
# | と 玉v銀v金 ・|四
# | ・ ・ ・ ・vと|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 2c3b
# --------------Trun(160) : Move from 2c to 3b--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | ・ ・ 角 ・ 飛|三
# | と 玉v銀v金 ・|四
# | ・ ・ ・ ・vと|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 160---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 161 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | ・ ・ 角 ・ 飛|三
# | と 玉v銀v金 ・|四
# | ・ ・ ・ ・vと|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 5d5c
# --------------Trun(161) : Move from 5d to 5c--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・ 角 ・ 飛|三
# | ・ 玉v銀v金 ・|四
# | ・ ・ ・ ・vと|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 161---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 162 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・ 角 ・ 飛|三
# | ・ 玉v銀v金 ・|四
# | ・ ・ ・ ・vと|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 2d2e
# --------------Trun(162) : Move from 2d to 2e--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・ 角 ・ 飛|三
# | ・ 玉v銀 ・ ・|四
# | ・ ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 162---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 163 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・ 角 ・ 飛|三
# | ・ 玉v銀 ・ ・|四
# | ・ ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 3c2d
# --------------Trun(163) : Move from 3c to 2d--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・ ・ ・ 飛|三
# | ・ 玉v銀 角 ・|四
# | ・ ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 163---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 164 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・ ・ ・ 飛|三
# | ・ 玉v銀 角 ・|四
# | ・ ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : B*3c
# --------------Trun(164) : Move from B* to 3c--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・v角 ・ 飛|三
# | ・ 玉v銀 角 ・|四
# | ・ ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：
# is_Check : True
# ------------------------------------------------------------------------
# ---------------------------------End Turn 164---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 165 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・v角 ・ 飛|三
# | ・ 玉v銀 角 ・|四
# | ・ ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 4d5d
# --------------Trun(165) : Move from 4d to 5d--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・v角 ・ 飛|三
# | 玉 ・v銀 角 ・|四
# | ・ ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 165---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 166 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・v角 ・ 飛|三
# | 玉 ・v銀 角 ・|四
# | ・ ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 3c5e+
# --------------Trun(166) : Move from 3c to e+--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・ ・ ・ 飛|三
# | 玉 ・v銀 角 ・|四
# |v全 ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：
# is_Check : True
# ------------------------------------------------------------------------
# ---------------------------------End Turn 166---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 167 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・ ・ ・ 飛|三
# | 玉 ・v銀 角 ・|四
# |v全 ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 5d5e
# --------------Trun(167) : Move from 5d to 5e--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・ ・ ・ 飛|三
# | ・ ・v銀 角 ・|四
# | 玉 ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：　角
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 167---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 168 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | と ・ ・ ・ 飛|三
# | ・ ・v銀 角 ・|四
# | 玉 ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：　角
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 3d4c
# --------------Trun(168) : Move from 3d to 4c--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | とv銀 ・ ・ 飛|三
# | ・ ・ ・ 角 ・|四
# | 玉 ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：　角
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 168---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 169 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 ・ 圭|二
# | とv銀 ・ ・ 飛|三
# | ・ ・ ・ 角 ・|四
# | 玉 ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：　角
# PLAYER 1
# Selected : B*2b
# --------------Trun(169) : Move from B* to 2b--------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 角 圭|二
# | とv銀 ・ ・ 飛|三
# | ・ ・ ・ 角 ・|四
# | 玉 ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 169---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 170 : 上(後手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 角 圭|二
# | とv銀 ・ ・ 飛|三
# | ・ ・ ・ 角 ・|四
# | 玉 ・ ・v金vと|五
# +---------------------------+
# 先手の持駒：
# RANDOM PLAYER
# 5a 4a 3a 2a 1a
# 5b 4b 3b 2b 1b
# 5c 4c 3c 2c 1c
# 5d 4d 3d 2d 1d
# 5e 4e 3e 2e 1e
# -------------------
# Selected : 2e2d
# --------------Trun(170) : Move from 2e to 2d--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 角 圭|二
# | とv銀 ・ ・ 飛|三
# | ・ ・ ・v金 ・|四
# | 玉 ・ ・ ・vと|五
# +---------------------------+
# 先手の持駒：
# is_Check : False
# ------------------------------------------------------------------------
# ---------------------------------End Turn 170---------------------------------
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# ------------------------Start Turn 171 : 下(先手)------------------------
# ------------------------------------------------------------------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ ・ 馬|一
# | ・ ・v玉 角 圭|二
# | とv銀 ・ ・ 飛|三
# | ・ ・ ・v金 ・|四
# | 玉 ・ ・ ・vと|五
# +---------------------------+
# 先手の持駒：
# PLAYER 1
# Selected : 1a2a
# --------------Trun(171) : Move from 1a to 2a--------------
# 後手の持駒：　角
#   5 ４ ３ ２ １
# +---------------------------+
# | 金 ・ ・ 馬 ・|一
# | ・ ・v玉 角 圭|二
# | とv銀 ・ ・ 飛|三
# | ・ ・ ・v金 ・|四
# | 玉 ・ ・ ・vと|五
# +---------------------------+
# 先手の持駒：
# is_Check : True
# ------------------------------------------------------------------------
# ---------------------------------End Turn 171---------------------------------
# ------------------------------------------------------------------------
#
#
# CHECK MATE : True
# GAME OVER : True
# 1

# %%
board = shogi.Board()
player1 = PolicyValuePlayer()
player1.isready()
player2 = PolicyValuePlayer()
player2.isready()

print('BBBBBB')
print(board)

print('11111')
print(player1.board)
temp = player1.select_move()
print(temp)

board.push_usi(temp)
player1.board.push_usi(temp)
print('BBBBBB')
print(board)
print('111111')
print(player1.board)
# Out:
# readyok
# readyok
# BBBBBB
#  r  b  s  g  k
#  .  .  .  .  p
#  .  .  .  .  .
#  P  .  .  .  .
#  K  G  S  B  R
# 11111
#  r  b  s  g  k
#  .  .  .  .  p
#  .  .  .  .  .
#  P  .  .  .  .
#  K  G  S  B  R
# 5d5c
# BBBBBB
#  r  b  s  g  k
#  .  .  .  .  p
#  P  .  .  .  .
#  .  .  .  .  .
#  K  G  S  B  R
# 111111
#  r  b  s  g  k
#  .  .  .  .  p
#  P  .  .  .  .
#  .  .  .  .  .
#  K  G  S  B  R

# %%
print(player2.board)
# Out:
#  r  b  s  g  k
#  .  .  .  .  p
#  .  .  .  .  .
#  P  .  .  .  .
#  K  G  S  B  R

# %%
bb_rotate_180()
# Out:
# id name policy_player
# option name modelfile type string default /Users/han/python-shogi/checkpoint/5_shogi_210913_1_100_10300
# usiok

# %%
make_input_features_from_board
# Out:
# <function shogi.features.make_input_features_from_board(board)>

# %%
def xx(temp):
    temp1 = '{:0=25b}'.format(temp)
    for i, s in enumerate(temp1):
        if i%5 == 0:
            print()
        print(s, end='')
    print('')

def move_plot(n):
    t_occupied = Occupied(BB_SQUARES[n] ,  BB_SQUARES[n])

    BB_BISHOP_ATTACKS = (BB_R45_ATTACKS[n][(t_occupied.r45 >> BB_SHIFT_R45[n]) & 7] |
                        BB_L45_ATTACKS[n][(t_occupied.l45 >> BB_SHIFT_L45[n]) & 7])

    BB_ROOK_ATTACKS = (BB_RANK_ATTACKS[n][(t_occupied.bits >> (((n // 5) * 5) + 1)) & 7] |
                        BB_FILE_ATTACKS[n][(t_occupied.l90 >> (((n % 5) * 5) + 1)) & 7])

    BB_PROM_BISHOP_ATTACKS = (BB_KING_ATTACKS[n] |
                        BB_R45_ATTACKS[n][(t_occupied.r45 >> BB_SHIFT_R45[n]) & 7] |
                        BB_L45_ATTACKS[n][(t_occupied.l45 >> BB_SHIFT_L45[n]) & 7])

    BB_PROM_ROOK_ATTACKS = (BB_KING_ATTACKS[n] |
                        BB_RANK_ATTACKS[n][(t_occupied.bits >> (((n // 5) * 5) + 1)) & 7] |
                        BB_FILE_ATTACKS[n][(t_occupied.l90 >> (((n % 5) * 5) + 1)) & 7])


    print('pawn')
    xx(BB_PAWN_ATTACKS[0][n])
    print('----------------')
    print('silver')
    xx(BB_SILVER_ATTACKS[0][n])
    print('----------------')
    print('gold')
    xx(BB_GOLD_ATTACKS[0][n])
    print('----------------')

    print('bishop')
    xx(BB_BISHOP_ATTACKS)
    print('----------------')
    print('rook')
    xx(BB_ROOK_ATTACKS)
    print('----------------')
    print('p_bishop')
    xx(BB_PROM_BISHOP_ATTACKS)
    print('----------------')
    print('p_rook')
    xx(BB_PROM_ROOK_ATTACKS)
    print('----------------')

# %%
move_plot(1)
# Out:
# pawn
#
# 00000
# 00000
# 00000
# 00000
# 00000
# ----------------
# silver
#
# 00000
# 00000
# 00000
# 00101
# 00000
# ----------------
# gold
#
# 00000
# 00000
# 00000
# 00010
# 00101
# ----------------
# bishop
#
# 00000
# 10000
# 01000
# 00101
# 00000
# ----------------
# rook
#
# 00010
# 00010
# 00010
# 00010
# 11101
# ----------------
# p_bishop
#
# 00000
# 10000
# 01000
# 00111
# 00101
# ----------------
# p_rook
#
# 00010
# 00010
# 00010
# 00111
# 11101
# ----------------

# %%
import random
for i in range(509):
    if i % 4 == 0:
        print('')
    print('0x{0:016X},'.format(random.randint(0, 0xffffffffffffffff)), end='')
    if i % 4 == 3:
        print('')
# Out:
# 0x0A82F6F3C159640B,0xB95B1031846C1C7F,0x69E32C60FD3643E3,0x381C66A41D4DF6CD,
#
# 0x4FCC7BACEDB68B00,0x7302AF66262C43C6,0x09A4B73AE746D4C4,0xAD1F87A976FC7D9C,
#
# 0xACA024799FD530FC,0x83FD4547EA1A90AF,0x536E97A9F7232E83,0x14832ECD2ADED7AE,
#
# 0x41971879E537BD93,0x2B9176693DA88BFA,0xD1DE7442388636D2,0xE238C62D02ADB2DA,
#
# 0x61D6B45F8614890B,0x1A628786CE61E55B,0xC842191B7EB5B343,0xAADDDFEE696CB11F,
#
# 0x3155594A8F643037,0x5853682E216EE7B3,0x08466AC278297E43,0x1A7FD0558334A9B3,
#
# 0x4EDDE2CFF1332134,0x4533A8F55193BF2D,0xC44350883750FC8C,0x0B5C95599BBDC428,
#
# 0x93D73DBC35E25B88,0x019985B723E78CE8,0x4FD4BA8B372AC19B,0xAA22EE53199B301C,
#
# 0xF092E1DE4F3E9B4C,0x140817965FF4F8A3,0x4712EE18A1662CE9,0x130FB5451390932B,
#
# 0x0127B33843967538,0xC66151F3A51C2EED,0x04B4EB791D2C9BB0,0x86775F6C56A636F0,
#
# 0x054C20DB1ABC1C61,0xEB8403E49BCD1DB9,0x2BA1D21A2BD9C5C6,0xE91DF9C71A6B7E74,
#
# 0xB8524D32BC019626,0x44A1DA2AE350E98A,0xB7EA85596E68362A,0x903FD02AC6BE2AE3,
#
# 0xE70369A537908E49,0x0EFB44161D7968C8,0xDAFD93AF780CDFD1,0x498CD0C10508EBC6,
#
# 0x419AB94AAC042F03,0x324ED74C40925EC1,0x1B6BE50E5B1664DD,0x00EB5C5B4F2BCE21,
#
# 0x36367AC41C5A6C63,0x2BB868DE18C2CAEA,0xB8144472FDD55DFA,0xC3186228368F7801,
#
# 0xA37A08F2C2BA0CCA,0x7059721EE4C08AA0,0x599F61A3FD854AB4,0x8CEBDB245A3A35CD,
#
# 0x1EEEC7F66F35DFCF,0xE9EEC6A436A127B5,0xD8B7A0B4719FDA9D,0x42A4965DEC8AEDE9,
#
# 0x095F44EC0B0C1290,0x878380818855D352,0xCC06E994B021A5E9,0xBDCA9860F1A6D97F,
#
# 0x9CC02C154D1F2688,0xFA9384ED2C252341,0x77B03BE32A54E80A,0x8BFAEED694F458F1,
#
# 0x4EAA89DEA9B9A30C,0xB3B686F248AA5DFB,0x94667435A30CB352,0xA92A3B7F4BDA3509,
#
# 0x75005BABE38B34B3,0xB95F44DB87B4D3B7,0x515B3519346ABB77,0xA6738DA6D0A1CC9A,
#
# 0xC42932F8D900BB6E,0xF8A20681747B062C,0x76A1951A09D7824B,0x972C0CD1C1F813AD,
#
# 0xB74E91B411CA6A24,0x63817E9392A53F90,0x9B8623D3B020F0CA,0x0F353A569095F3FA,
#
# 0xB8863A6955A0F518,0x0839ACC7D0AD8E26,0x59E511A4D6844216,0xC3ACE59741440FF6,
#
# 0xD9BA10AB348ECF52,0x62642244ABC52C0D,0x098178992AE28E45,0xB7995300170143C1,
#
# 0x348AF2D0B48A387C,0x9869AED988D87ECC,0xED90B7307CB48850,0x82C58794C295163F,
#
# 0x144B6762E533D3CD,0x4D8E12010E4EC9BA,0xB84B980C5FF46144,0xAF97EE21D0A45300,
#
# 0x59B804847B4BF71C,0x542B3641205CE84D,0x4337D06F04191862,0x116888496E89E431,
#
# 0xA3DB081738200F35,0xF34C6A301E1CDDBE,0x76B30E4B96E0AEA2,0xF0C12A3A950A4B4F,
#
# 0x3C6A9C0AE8374752,0x5E4F9132C48724C3,0x2C6B5777A9D57FCF,0x76D41F493C7FB868,
#
# 0x03B8C708A8DBFD41,0x975E23E92BFF1A57,0xEC6A847F73968333,0xE10389BDCC1AEF3E,
#
# 0x653CC5FA28DA6A57,0xD0E6C3BD670CC1E0,0x55BA9D93C1FC2F27,0x306E68EDFBCB4A44,
#
# 0x80E67030D2CAB18A,0x6A1DEDFF7CADC261,0xE179351B7F004AC5,0x5502DB4E1B3510B4,
#
# 0xE029AEE9E2D0B82B,0x502597042205E50E,0x7F94A82D8D47BD7E,0x34A475BE4F0A5428,
#
# 0x829BA020C797F83C,0x9F0719CF6843219A,0x3E6CFEE32CBF6408,0x5B8E3FD1E2AF598F,
#
# 0x82B4145C23F03E9E,0xC68C3C863ABB2A3D,0xB1FC1CB1A8536644,0x479643E8FF8C8EC2,
#
# 0x181E760D71D3E561,0xB669E82471F28793,0x0C6D41D582031024,0x4DE9095962B0AC54,
#
# 0x938806873ABB5182,0x4D667604E9F9C08F,0x41AADC7DB58CC886,0x77D258CFB08B5843,
#
# 0x1E76BC2165D13335,0xB213EF75BF303886,0x80719F3F34363A9A,0x92E743FBD3E98DEC,
#
# 0x48BF6788D3F16709,0x9612A08DDB93962A,0xEFDC31F0ECB0DF82,0x4903B88229B62F57,
#
# 0x5BAE409C265A2E5D,0x8775C10EB69ACEF4,0x0A8C7A712B3F7309,0x760B0CF4863EDAB5,
#
# 0x1857304DF4A3BAAD,0xC068116B397ABE58,0xD79166B616EE722E,0x603FA663183B628D,
#
# 0xCD798DBBB5B0A57E,0x40F33825FC6A756B,0x385AF47F44615F1A,0x67A509FC9FCE7D6A,
#
# 0x07A8609DB4E69116,0x8DF636498063E62E,0x7538DB907F451416,0x936FD02450B02D62,
#
# 0x65FE282AA335933F,0xE9796ED0AB98DB75,0x8E44651BAD9891B2,0xC811F4CC48AC1084,
#
# 0x7230C713BD3DCCC3,0xD4C9E832EF86207E,0xC29B846DDD35B3BB,0x9F1A81392648F5CD,
#
# 0xE93307A3F14F3FF5,0xECA4F1958E8C9B7A,0xF50539695E507457,0xC1081A0E51164D57,
#
# 0x604B107632FD54D9,0xCB943F66760CDD19,0xA7EA5E4C044F7830,0x58BB13CC3FE58E88,
#
# 0x009D49AC949BD95F,0x38897F4B232F89F7,0xA49C607D82CC6592,0x9D686232902EC8DC,
#
# 0x354580F97988B088,0xA70D257DF146CFC2,0x47CE683B1D54F3F5,0x6E393E92830273DE,
#
# 0x15803C333810C552,0x3BB9A60931865D4F,0xB44FDF510E40E221,0x0DEAA6F6BD2D5118,
#
# 0xA6696FB9DB950BE9,0xA764C3F06B6241E2,0xFB8E71DF066E6F55,0xF1B8BBCA01BA5A17,
#
# 0x342C5B4ACD4D41FC,0x2526C7C744EB042B,0xCA5E13B90467C648,0xBC64FD4AA204A40B,
#
# 0x0891A6C24B6F6B9B,0xD6F554FC66915D18,0xBD8513DF8E3085CC,0xAEAEAF94F53C5F9A,
#
# 0x0048A224E4B7AEF1,0x770DADF66E168DA4,0x8652147503ABF615,0x686AF49D804134CE,
#
# 0xB29E805AA988F41D,0x275E4D1206A3085F,0xD1B579200C73C187,0x522732FA4BA49B3F,
#
# 0xA11F82B1137109EF,0xDE3AD313972CCFCC,0x78C8DA39DEBD3914,0x5909B3676F3355A7,
#
# 0xE08376988F125C14,0x712BA915020210F2,0x13B73663F1487F28,0x0D6E1C107C0C43EF,
#
# 0x5B8213EBD95D1077,0x0542C90956F8CA40,0xF01FF42DA1C0F17B,0x506974D92BFCCB1A,
#
# 0xCCA11E97C0D79C8B,0x195C9D22E147EA58,0x8CA3AD0FE46748B9,0x9F844CF05E133677,
#
# 0x1F26B502FEAF648A,0x584D950B2C0FE5D5,0xC48D087FDCB38402,0xFFA93067CA929C05,
#
# 0x879C39607AEC1F14,0xBB94CC19F8A51D07,0x553A9C8B279A845C,0x94CF12B7E173616C,
#
# 0x4C53B881BF49016E,0xA25813DC296A93F9,0x975CA60C25D7A219,0x7D05F23FF88960DC,
#
# 0x8AD7FD3BC3FA66CC,0x51498002BAE678F4,0x33B9E09428625F49,0xEB712788E353A6CB,
#
# 0xECC7021D723B89C0,0x2504974020C4F381,0x31E81B5309412867,0x3386CE1E473A517C,
#
# 0xA73C3C13B15F4F2F,0x9E6B712285F3480D,0xD5E79A373ADCC6E7,0xBFDDD189AD478E0C,
#
# 0xC45492B245CCEC6A,0x70B17157C1BA014F,0x8133C73F435BC3CA,0xF1388424FB6CFFCB,
#
# 0x7C6561F2E9D7A8C7,0xE5536CC53785449E,0xCFF845D978F0CD47,0x35BF1162CB1BB6A7,
#
# 0x0E8A0DE03E1F4163,0x6957C84503897485,0x5779C6F277F16A72,0xBEFC7A44A9507F0A,
#
# 0xE61164C16F9D5267,0xF907E57FEC016488,0x7DA7011CB5CF1014,0x125105C76811F182,
#
# 0x9EC4514018022B5B,0x15ABDF0C73C5D8AA,0x4538DDC547E8EEFA,0xE5ED2D6729C97720,
#
# 0x22A09655798289B0,0xC0D058D10D6C58D6,0xCEF1818F84C9FA1E,0xA85F6F45C753471D,
#
# 0x2AB0A009219DC207,0xB817E3FBB4D7A689,0x25BDC56BCF24E3A8,0x49F29EC4F39F2D0B,
#
# 0xFFF77D24F77754FD,0x8F70F71500BCA30A,0x68556B4BC56F6E08,0x07C179DDD11AC28F,
#
# 0xB33C6F76896AD829,0x21900EDC7C8383A8,0x49FB9AB09DD25117,0x3CCA535B8E1CA84C,
#
# 0x2E78F857A266CD1A,0x10EC4ACC8F60C19C,0xED555BD8EB88AC6B,0x891E44CC92710A0C,
#
# 0xFB991119710DF573,0x419BA595EB2EC53E,0x5D12D2B95CFC4B6F,0x304C9BB159D21842,
#
# 0xF1B76AEFC442DC4D,0xA43D452F0BBEAF05,0x0D5140FA3F81D074,0xBEB2E8C64A67564C,
#
# 0x2D4A170B54542E32,0x6A83FAB2C78CCDEE,0x844FE07C258FAB07,0x049E5669F98041FC,
#
# 0xA11EBD5E3D360521,0x5122E401D894A82F,0x5B5E519F173F028F,0x610F281131DF4BA0,
#
# 0xD314690C841A4F3C,0x61542D801C4B8406,0xE48782CBA6CE3931,0x36D56222F4A28EE4,
#
# 0x5AEB5ACEC3D5C12F,0x21FF996ED993BD8B,0x88612F7ACA547C3B,0xEF55CF7C288C3A99,
#
# 0x61626E778A108677,0x1E35BEE7A1EF02E2,0xDF92BCEF42D2A1D9,0xA78CE5E947FC78F4,
#
# 0x692BB4CFFED78AB9,0x74A12968919B1AF7,0x2C3CAF6916626668,0xEDA1A4A1D56E0F97,
#
# 0x179324EB9BD7443A,0x60CE2C2CF9E892FF,0x511CD51938C3412D,0x0D4139D5912221F5,
#
# 0x80C594E855FB029E,0xCCFA972DB21D8F5A,0xF4837EC2F04F7F79,0x4E9B37812E43C226,
#
# 0xAE2285C74FAA5C4C,0xB24CB66A381741CD,0xFB0FF1937B13BF82,0xB622A3FD5DDD4F39,
#
# 0x8255A2EEFB6DB0C7,0x61914B35CDA8248C,0x9B03B7D501CDD301,0xA88D93FBC7EBEB12,
#
# 0x5EF8C43408F38EAA,0x8BC79D0CCA3CFB75,0xDDC696894431B426,0xED6994AB0FD0BAE8,
#
# 0xFB7665693C9EA9B3,0xE8F0795E247F59CE,0x7B6F2BB39FBEF809,0x890AA99198FF8296,
#
# 0xD8E113483791E23F,0xB219F834F1F1CD9E,0x49CCE961B5F70A64,0x5D8867D363A1F438,
#
# 0xC7E398BF9AEA87DC,0x4A31FE4576338779,0x9FCC8B4D923ECBD3,0x87134308913DF66C,
#
# 0x83E9DFE495155D8B,0xCD5770CDEC44D3DA,0xF4DD84D481F3EA2F,0x69781983AD28A647,
#
# 0x4ED7EF3212F0EB61,0xE18A757DE337613E,0x414A3E27B682FB97,0x4398E97923C97762,
#
# 0x71CE16C46C682E01,0x56A365851570D467,0x8B00067B67ED440D,0x633698A115187C69,
#
# 0x6E27C065D4BEAA88,0xAECC7CC28FA84C27,0xFB8BC8D8773835F4,0x5984D5F23991C545,
#
# 0xEEB8E705B3288DCF,0xBE749F37D1029CA4,0xB26454743BDECB6D,0xA8B4DDCD1C38DC9E,
#
# 0x1A8D0C1A7A585C45,0x67352A4F7CC28970,0xA7A7393D440A3051,0x90726E9996AC1952,
#
# 0x8655B89173858652,0x74A77127CE824637,0x7CB9CE5B9E49B74D,0x219096A6B73831F3,
#
# 0x8317C43FBA4D62EE,0x9EC221623937AB30,0x979C3881DD38F35B,0x535120A9A826E7A3,
#
# 0x9BAD2BA58CF4ADAC,0xE174D985FB365B45,0x91EEECD21B8D00F3,0xB5D690304B826C2A,
#
# 0x0BF49AA0907196B3,0x7B5CA664EBB7B0E7,0x44926BDB5833DF2E,0x0BE698837DF31CAF,
#
# 0xEF8E91EBB5AF9ABC,0xBEA8EE329D5C5CDD,0x6587053FEFE2FCC1,0x6D668039BF4F83A3,
#
# 0x9B960ECFDE6EEBB2,0x5FA1F19D1220EAD1,0x3025237AEC029A73,0xF41AEAD69BB6EF67,
#
# 0xED76A53DBD55D479,0x370F737602321AC8,0x54477E4DE462C7E4,0x115514C83A2BB129,
#
# 0x6FF92DEE13FBF4E8,0xDB9885E8DF84F43C,0x614BFC86D0775395,0xE4A830F2EF1E174C,
#
# 0xF8734ADB82F73309,0xF03208A67B38EB64,0xC361F287481DDED2,0xA3C8BE2C3CD068CA,
#
# 0xC20493D805F0C880,0x1423CFF2E8FB18E8,0x6F5524FA696FD6AF,0x99D5271557CC26F9,
#
# 0xCF4E7CABE8B00D5C,0x621A37A092DB36DD,0x85FFE1FD3B3041DB,0x724397C4CD2BDC62,
#
# 0xA77EA237788C99A6,0xB811DFF94760C1F8,0x8606EC3491EB4F57,0x980F1768B64CEBE5,
#
# 0xC39B73CF00C3EFC4,0x07EED4869C1916CA,0x8B6296E3E131D475,0xEBEC6E3E800DEEA1,
#
# 0xE32A5CB52A142890,0x6A293451746780EF,0x6D3CB3080F7F7B67,0x5B131B7E1E679EA8,
#
# 0xA20942111D4D51F4,0x7449CF39BD6F67FE,0x48C1352C79002610,0x56BBDF153CA4A54E,
#
# 0x8A93A35BB1853392,0x6A1F3F745E953D64,0x3FC19AEF3D5EC00B,0x27D4E2781FF6708D,
#
# 0x6440EE0F4EEA2BBD,0xDB16390590AFC128,0x4AA8B2AAF02B3246,0x6554E5FED6568381,
#
# 0x3FE400D6EC8026E5,0x9D2FAD5F12DB4D51,0x7D3E9A3D36F829C8,0x9FFDFE0941C33C9E,
#
# 0x00D146D7F43CF281,0xF0F12DAC0F5CF7C5,0xCB6F7297D584839D,0x19A9898BFFD6281F,
#
# 0x09B970F0425BC53B,0xF208E9F4A10262BC,0x883E5AE7D3450CB8,0x8CF7133E03060357,
#
# 0x97771BC6E9BE410F,0x5BA35BB613D8A257,0x8EA1B54157FE307F,0xE5EFDBC3888EC96E,
#
# 0x0105ACA157925E16,0x5A41F3BB8F717B8B,0x769CFAED43991080,0x0C16D93D4E4339DE,
#
# 0x838AD3CD74EBEB8E,0x1D03762A1C906714,0x4F94A185DD2A5BAE,0xC456D6502266625D,
#
# 0xAB59E252DF780D62,0xA618068001F9B9A2,0x6419689E1930366F,0xFB7AE9C7792A1ACE,
#
# 0x1B21A13DD138E62C,0x69D1EC179545767A,0x27C3627F9304DE85,0xE6573C166BCA52A1,
#
# 0x0AE95CCE3B8D8787,0xBBAA3617D1B1B2E6,0x8706A69573A73DBD,0xE4C5D18627F58CE9,
#
# 0xB96A3C3893177E4C,0xAF9DDE08E96B1992,0xBCC5B9E5D5189EE4,0xD465D3EDBAB54474,
#
# 0x3DFD15F6AC928541,0x7368A83E7D2F9D2A,0xE6836D77384B9077,0xC978442A52BDE15A,
#
# 0xF5AD667702E69E7F,0x423C12091E60E987,0xA169B0DB9374F0C7,0x6AF2ECC3C14DFE35,
#
# 0x21CBB229E8F329C2,
